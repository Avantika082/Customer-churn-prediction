# %% [markdown]
# # Customer churn prediction

# %% [markdown]
# ## Using linear and tree based models for churn prediction

# %% [markdown]
# #### Import the data

# %%
import numpy as np , pandas as pd , matplotlib.pyplot as plt , seaborn as sns

# %%
import os

# %% [markdown]
# ### Import the data

# %%
# !kaggle datasets download -d shantanudhakadd/bank-customer-churn-prediction -p ../Dataset/data --unzip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/shantanudhakadd/bank-customer-churn-prediction
# License(s): other

# %%
try:
    files = os.listdir('../Dataset')
    print("Files found:", files)
except Exception as e:
    print("Access error:", e)
# Out:
# Files found: ['Churn_Modelling.csv', 'data']

# %%
df = pd.read_csv('../Dataset/Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df=df.drop(['CustomerId','Surname','RowNumber'],axis=1)
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
import math
cols=['CreditScore','Geography','Gender','Age','Tenure','Balance','NumOfProducts','HasCrCard','IsActiveMember','EstimatedSalary']
n = len(cols)
rows = math.ceil(n/3)

# %% [markdown]
# #### Data Visualization

# %%
plt.figure(figsize=(15,5*rows))
for i,col in enumerate(cols):
    plt.subplot(rows,3,i+1)
    sns.boxplot(x=col,data=df)
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
print(cols)
# Out:
# ['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary']

# %%
plt.figure(figsize=(12,15))

sns.heatmap(data=df.corr(numeric_only=True),annot=True,cmap='coolwarm')
plt.show()

# %%
sns.countplot(x='Exited',data=df)
plt.title('Churn Distribution')
# Out:
# Text(0.5, 1.0, 'Churn Distribution')

# %% [markdown]
# ### Balance the imbalanced data

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
categorical_cols = df.select_dtypes(include=['object']).columns
print(categorical_cols)
# Out:
# Index(['Geography', 'Gender'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

labelEncoder = LabelEncoder()

for cols in categorical_cols:
    df[cols] = labelEncoder.fit_transform(df[cols])

df
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619          0       0   42       2       0.00              1
# 1             608          2       0   41       1   83807.86              1
# 2             502          0       0   42       8  159660.80              3
# 3             699          0       0   39       1       0.00              2
# 4             850          2       0   43       2  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 9995          771          0       1   39       5       0.00              2
# 9996          516          0       1   35      10   57369.61              1
# 9997          709          0       0   36       7       0.00              1
# 9998          772          1       1   42       3   75075.31              2
# 9999          792          0       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
x = df.drop('Exited',axis=1)
y = df['Exited']
x
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619          0       0   42       2       0.00              1
# 1             608          2       0   41       1   83807.86              1
# 2             502          0       0   42       8  159660.80              3
# 3             699          0       0   39       1       0.00              2
# 4             850          2       0   43       2  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 9995          771          0       1   39       5       0.00              2
# 9996          516          0       1   35      10   57369.61              1
# 9997          709          0       0   36       7       0.00              1
# 9998          772          1       1   42       3   75075.31              2
# 9999          792          0       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
conda install -c conda-forge imbalanced-learn
# Out:
# Channels:
# Note: you may need to restart the kernel to use updated packages.
#
#  - conda-forge
#  - defaults
# Platform: win-64
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\hp\anaconda3\envs\p001
#
#   added / updated specs:
#     - imbalanced-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     imbalanced-learn-0.13.0    |     pyhd8ed1ab_0         141 KB  conda-forge
#     openssl-3.5.0              |       ha4e3fda_0         8.6 MB  conda-forge
#     sklearn-compat-0.1.3       |     pyhd8ed1ab_0          22 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         8.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   imbalanced-learn   conda-forge/noarch::imbalanced-learn-0.13.0-pyhd8ed1ab_0
# ...

# %%
df.iloc[:,2]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9995    1
# 9996    1
# 9997    0
# 9998    1
# 9999    0
# Name: Gender, Length: 10000, dtype: int64

# %%
plt.figure(figsize=(15,5*rows))
for i,col in enumerate(cols):
    plt.subplot(rows,3,i+1)
    sns.stripplot(x=col,y=y,data=df, jitter = True , alpha=0.3)
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
from imblearn.over_sampling import SMOTENC
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,stratify=y,random_state=42)

smotenc = SMOTENC(categorical_features = [1,2]  ,random_state=42)
x_train_resampled,y_train_resampled = smotenc.fit_resample(x_train,y_train)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report,accuracy_score,recall_score,make_scorer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
sns.countplot(x=y_train, hue = y_train)
# Out:
# <Axes: xlabel='Exited', ylabel='count'>

# %% [markdown]
# ### Training Random Forest Classifier without balancing the data

# %%
rf = RandomForestClassifier(class_weight = 'balanced' , random_state=42)

recall = make_scorer(recall_score)

param_grid = {
    'n_estimators' : [100,200],
    'max_depth' : [None,10,20],
    'min_samples_split' : [2,5]
}

grid = GridSearchCV(
    estimator = rf,
    param_grid = param_grid,
    scoring = recall,
    refit = 'recall',
    cv=5
)

grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=42),
#              param_grid={'max_depth': [None, 10, 20],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [100, 200]},
#              refit='recall',
#              scoring=make_scorer(recall_score, response_method='predict'))

# %%
print("Best params :", grid.best_params_)
print("Best score : " , grid.best_score_)
# Out:
# Best params : {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 200}
# Best score :  0.6171306118075645

# %%
x_train_resampled
# Out:
#        CreditScore  Geography  Gender  Age  Tenure        Balance  \
# 0              735          0       0   53       8  123845.360000
# 1              518          0       1   38       3   90957.810000
# 2              572          1       0   54       9   97382.530000
# 3              619          0       0   35       4   90413.120000
# 4              608          2       0   41       1   83807.860000
# ...            ...        ...     ...  ...     ...            ...
# 11939          811          1       1   48       1  120493.324274
# 11940          456          0       0   43       8       0.000000
# 11941          743          2       1   57       4       0.000000
# 11942          651          1       1   56       2  136420.202385
# 11943          681          0       1   62       3   81222.009158
#
#        NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0                  2          0               1    170454.930000
# ...

# %%
sns.countplot(x=y_train_resampled , hue = y_train_resampled)
plt.title('Churn Distribution')
# Out:
# Text(0.5, 1.0, 'Churn Distribution')

# %% [markdown]
# ### Training Random Forest Classifier using balanced data

# %%
grid.fit(x_train_resampled,y_train_resampled)
# Out:
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=42),
#              param_grid={'max_depth': [None, 10, 20],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [100, 200]},
#              refit='recall',
#              scoring=make_scorer(recall_score, response_method='predict'))

# %%
print("Best params :" , grid.best_params_)
print("Best score :" , grid.best_score_)
# Out:
# Best params : {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 200}
# Best score : 0.8463120343698968

# %%
y_pred = grid.predict(x_test)
print(classification_report(y_pred,y_test))
print(accuracy_score(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88      1891
#            1       0.66      0.55      0.60       609
#
#     accuracy                           0.82      2500
#    macro avg       0.76      0.73      0.74      2500
# weighted avg       0.81      0.82      0.82      2500
#
# 0.8208

# %% [markdown]
# ### Scaling the data

# %%
sc = StandardScaler()
scaled_x_tre = sc.fit_transform(x_train_resampled)
scaled_x_test = sc.transform(x_test)

# %% [markdown]
# ### Training and hyperparameter tuning of KNN , Logistic regression and SVM

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import svm

# %%
model_params = {
    'svm' : {
        'model' : svm.SVC(gamma = 'auto'),
        'params' : {
            'C' : [1,20,40] ,
            'kernel' : ['rbf' , 'linear']
        }

    },
    'LogisticRegression' : {
        'model' : LogisticRegression(solver = 'liblinear' ),
        'params' : {
            'C' : [1,30,50]
        }
    },
    'Kneighbors_classifier' : {
        'model' : KNeighborsClassifier(),
        'params' : {
           'n_neighbors' : [1,10,15,20,25,30]
        }
    }
}

# %%
scores =[]

for model_name,mp in model_params.items():
    clf = GridSearchCV(mp['model'] , mp['params'] , cv=5 , return_train_score = False)
    clf.fit(scaled_x_tre,y_train_resampled)
    scores.append({
        'model' : model_name ,
        'best_score' : clf.best_score_ ,
        'best_params' : clf.best_params_
    })

# %%
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                    model  best_score                best_params
# 0                    svm    0.827280  {'C': 1, 'kernel': 'rbf'}
# 1     LogisticRegression    0.748580                   {'C': 1}
# 2  Kneighbors_classifier    0.806768        {'n_neighbors': 10}

# %% [markdown]
# #### Random forest after balancing the data is giving the most accurate results
